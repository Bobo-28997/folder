# %% [markdown]
# HM 1 Bowen Bao

# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib as mpl
import seaborn as sns

# %%
df = pd.read_csv('https://vincentarelbundock.github.io/Rdatasets/csv/datasets/mtcars.csv')

# %%
df.head(5)
# Out:
#             rownames   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df['cyl']
# Out:
# 0     6
# 1     6
# 2     4
# 3     6
# 4     8
# 5     6
# 6     8
# 7     4
# 8     4
# 9     6
# 10    6
# 11    8
# 12    8
# 13    8
# 14    8
# 15    8
# 16    8
# 17    4
# 18    4
# 19    4
# 20    4
# 21    8
# 22    8
# 23    8
# 24    8
# 25    4
# 26    4
# 27    4
# 28    8
# 29    6
# 30    8
# 31    4
# Name: cyl, dtype: int64

# %% [markdown]
# 4, 6 and 8

# %%
df.groupby('cyl')

# %%
df.groupby('cyl')[['mpg']].mean()
# Out:
#            mpg
# cyl
# 4    26.663636
# 6    19.742857
# 8    15.100000

# %%
df['mpg'].hist()
plt.xlabel('Miles per Gallon')
plt.ylabel('Count of Automobiles')
# Out:
# Text(0, 0.5, 'Count of Automobiles')

# %%
from matplotlib import pyplot as plt

plt.scatter(df['cyl'], df['mpg'])
plt.title("Miles per gallon of Automobiles with different numbers of cylinders")
plt.xlabel("Number of Cylinders")
plt.ylabel("Miles per Gallon")
# Out:
# Text(0, 0.5, 'Miles per Gallon')

# %% [markdown]
# I'm choosing the easy way out, so I will use the dataset "The Ultimate Halloween Candy Power Ranking," which Professor Greg used in his Data Analysis in Social Sciences class as an example.
#
# It's a dataset about what kind of candy people like the msot. Data was collected by creating a website where participants were shown presenting two fun-sized candies and asked to click on the one they would prefer to receive.
#
# Citation will be: FiveThirtyEight. "The Ultimate Halloween Candy Power Ranking." *Kaggle*, Rachael Tatman, 2018, https://www.kaggle.com/datasets/fivethirtyeight/the-ultimate-halloween-candy-power-ranking. Accessed 2/2/2025.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/fivethirtyeight/data/master/candy-power-ranking/candy-data.csv')

# %%
df.head(5)
# Out:
#   competitorname  chocolate  fruity  caramel  peanutyalmondy  nougat  \
# 0      100 Grand          1       0        1               0       0
# 1   3 Musketeers          1       0        0               0       1
# 2       One dime          0       0        0               0       0
# 3    One quarter          0       0        0               0       0
# 4      Air Heads          0       1        0               0       0
#
#    crispedricewafer  hard  bar  pluribus  sugarpercent  pricepercent  \
# 0                 1     0    1         0         0.732         0.860
# 1                 0     0    1         0         0.604         0.511
# 2                 0     0    0         0         0.011         0.116
# 3                 0     0    0         0         0.011         0.511
# 4                 0     0    0         0         0.906         0.511
#
#    winpercent
# 0   66.971725
# 1   67.602936
# 2   32.261086
# 3   46.116505
# 4   52.341465

# %%
sns.histplot(data=df, x="sugarpercent", y="winpercent")
plt.xlabel('percent of sugar in the candy')
plt.ylabel('percent of being preferred for Halloween')
# Out:
# Text(0, 0.5, 'percent of being preferred for Halloween')

# %%
plt.scatter(df['sugarpercent'], df['winpercent'])
plt.xlabel("ercent of sugar in the candy")
plt.ylabel("percent of being preferred for Halloween")
# Out:
# Text(0, 0.5, 'percent of being preferred for Halloween')
